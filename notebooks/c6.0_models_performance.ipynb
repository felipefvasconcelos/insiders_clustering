# %% [markdown]
# # 0.0. BUSINESS PROBLEM

# %% [markdown]
# ## 0.1. Challenge

# %% [markdown]
# Find who are most valuable customers to be part of "Insiders" group program.

# %% [markdown]
# ## 0.2. Business Questions

# %% [markdown]
# 1. Who are the customers elegible to participate of Insiders group?
# 2. How many customers will be part of the group?
# 3. What are main characteristics of these customers?
# 4. What is the revenue participation percentaga from Insiders group?
# 5. What is the expected revenue for the next few months from Insiders group?
# 6. What conditions a customer must meet to be an Insider?
# 7. What condisions a customer must meet to be excluded from Insiders group?
# 8. How to ensure that Insiders group is better than the rest of the customer base?
# 9. What can Marketing do to increase revenue?

# %% [markdown]
# # 1.0. FUNCTIONS & LIBS

# %% [markdown]
# ## 1.1. Imports

# %%
import re
import datetime
import optuna

import numpy      as np
import pandas     as pd
import seaborn    as sns
import umap.umap_ as umap

from pandas_profiling    import ProfileReport
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

from plotly        import express       as px
from sklearn       import cluster       as C
from sklearn       import metrics       as M
from sklearn       import mixture       as mx
from sklearn       import manifold      as mn
from sklearn       import ensemble      as en
from sklearn       import decomposition as dc
from sklearn       import preprocessing as pp
from matplotlib    import pyplot        as plt
from matplotlib    import colormaps     as cm
from scipy.cluster import hierarchy     as hc

# %% [markdown]
# ## 1.2. Helper Functions

# %%
pd.options.mode.chained_assignment = None

# Defining an objective function to be optimized
def bayesian_opt_objective(trial):
    eps = trial.suggest_float('eps', 0.30, 0.40, step=0.005)
    min_samples = trial.suggest_int('min_samples', 5, 50, step=5)

    # Defining the model
    dbscan_model = C.DBSCAN(eps=eps, min_samples=min_samples, n_jobs=-1)

    # Training the model and predicting
    labels = dbscan_model.fit_predict(X)

    # Performance
    sil = M.silhouette_score(X, labels, metric='euclidean')

    return sil

# %% [markdown]
# # 2.0. DATA DESCRIPTION

# %% [markdown]
# ## 2.1. Variables

# %% [markdown]
# **Invoice Number** - unique identifier of each transaction
#
# **Stock Code Product** - item code
#
# **Description Product** - item name
#
# **Quantity** - quantity of each item from a transaction
#
# **Invoice Date** - transaction day
#
# **Unit Price** - item price
#
# **Customer ID** - unque customer identifier
#
# **Country** - country where customer lives

# %% [markdown]
# ## 2.2. Load Data

# %%
df_raw = pd.read_csv('../data/raw/Ecommerce.csv', encoding='iso-8859-1')
df_raw = df_raw.drop(columns = 'Unnamed: 8')

# %% [markdown]
# ## 2.3. Rename Columns

# %%
cols_new = ['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date', 'unit_price', 'customer_id', 'country']
df_raw.columns = cols_new

# %% [markdown]
# ## 2.4. DF Dimensions

# %%
print('Number of rows: {}'.format(df_raw.shape[0]))
print('Number of columns: {}'.format(df_raw.shape[1]))
# Out:
# Number of rows: 541909
# Number of columns: 8

# %% [markdown]
# ## 2.5. Check NA and Duplicates

# %%
# check NA
print('Number of NAs:')
print(df_raw.isna().sum())

# check duplicates
print('\nNumber of Duplicated:')
print(df_raw.duplicated().sum())
# Out:
# Number of NAs:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64
#
# Number of Duplicated:
# 5269

# %%
# df_raw[df_raw.duplicated(keep=False)].sort_values(by=['customer_id','invoice_no', 'stock_code']).tail(15)
# # after investigating duplicated rows, it was decided to consider them as authentic transactions

# %% [markdown]
# ### 2.5.1. Replace NA

# %%
# separate rows with missing costumers
df_raw_missing = df_raw.loc[df_raw['customer_id'].isna(), :]

# %%
# create reference
df_backup = pd.DataFrame(df_raw_missing['invoice_no'].drop_duplicates())
df_backup['customer_id'] = np.arange(19000, (19000+len(df_backup)), 1)

# merge original with reference data
df_raw = pd.merge(df_raw, df_backup, on='invoice_no', how='left')

# coalesce
df_raw['customer_id'] = df_raw['customer_id_x'].combine_first(df_raw['customer_id_y'])

# drop extra columns
df_raw = df_raw.drop(columns=['customer_id_x', 'customer_id_y'], axis=1)

# %% [markdown]
# ## 2.6. Check DTypes

# %%
df_raw.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# country          object
# customer_id     float64
# dtype: object

# %% [markdown]
# ### 2.6.1 Change DTypes

# %%
df_raw = df_raw.astype({'customer_id': 'int64'})
df_raw['invoice_date'] = pd.to_datetime(df_raw['invoice_date'], format='%d-%b-%y')

# %%
df_raw.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# country                 object
# customer_id              int64
# dtype: object

# %% [markdown]
# ## 2.7. Descriptive Analysis

# %%
num_attributes = df_raw.select_dtypes(include=['int64', 'float64'])
cat_attributes = df_raw.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ### 2.7.1. Numerical Attributes

# %%
# central tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# dispersion - std deviation, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(np.min)).T
d3 = pd.DataFrame(num_attributes.apply(np.max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# concatenate results
df_num_att = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T. reset_index()
df_num_att.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

# %%
df_num_att
# Out:
#     attributes       min      max      range          mean    median  \
# 0     quantity -80995.00  80995.0  161990.00      9.552250      3.00
# 1   unit_price -11062.06  38970.0   50032.06      4.611114      2.08
# 2  customer_id  12346.00  22709.0   10363.00  16688.840453  16249.00
#
#            std        skew       kurtosis
# 0   218.080957   -0.264076  119769.160031
# 1    96.759764  186.506972   59005.719097
# 2  2911.408666    0.487449      -0.804287

# %%
# need further investigations: unit_price = 0, and quantity < 0

# %% [markdown]
# ### 2.7.2. Pandas Profiling

# %%
# pd_profile = ProfileReport(df_raw)
# pd_profile.to_file('output_df_raw_02R.html')

# %% [markdown]
# # 3.0. DATA FILTERING

# %%
df_raw_3 = df_raw.copy()

# %% [markdown]
# ## 3.1. Data Filtering Analysis

# %% [markdown]
# ### 3.1.1. unit_price
# filter prices lower than 0.01

# %%
# investigating prices = 0
df_raw_3[df_raw_3['unit_price']<=0.01].sample(5)
# Out:
#        invoice_no stock_code    description  quantity invoice_date  \
# 428764     573497      21642          check      -138   2017-10-29
# 280745     561489      84905            NaN        -2   2017-07-25
# 510117     579429      20711  lost in space       -98   2017-11-27
# 171733     551459      22173            NaN       -30   2017-04-26
# 517719     580087     84341B            NaN        -2   2017-11-29
#
#         unit_price         country  customer_id
# 428764         0.0  United Kingdom        22210
# 280745         0.0  United Kingdom        21370
# 510117         0.0  United Kingdom        22579
# 171733         0.0  United Kingdom        20467
# 517719         0.0  United Kingdom        22618

# %%
# investiating prices = 0.001
df_raw_3[df_raw_3['unit_price']==0.04]
# Out:
#        invoice_no stock_code                 description  quantity  \
# 217060     555876      16045  POPART WOODEN PENCILS ASST       100
# 221726     556267      16045  POPART WOODEN PENCILS ASST       500
# 228959     557006      16045  POPART WOODEN PENCILS ASST       100
# 229052     557009      16045  POPART WOODEN PENCILS ASST       100
# 229499     557057      16045  POPART WOODEN PENCILS ASST       100
# ...           ...        ...                         ...       ...
# 492556     578126      16045  POPART WOODEN PENCILS ASST       100
# 506043     579124      16045  POPART WOODEN PENCILS ASST       100
# 506918     579161      16045  POPART WOODEN PENCILS ASST       100
# 523461     580513      16045  POPART WOODEN PENCILS ASST       100
# 525404     580619      16045  POPART WOODEN PENCILS ASST       100
#
#        invoice_date  unit_price         country  customer_id
# 217060   2017-06-05        0.04  United Kingdom        15799
# 221726   2017-06-07        0.04  United Kingdom        13694
# 228959   2017-06-14        0.04  United Kingdom        14282
# 229052   2017-06-14        0.04  United Kingdom        14321
# 229499   2017-06-14        0.04  United Kingdom        16843
# ...             ...         ...             ...          ...
# 492556   2017-11-21        0.04  United Kingdom        16900
# 506043   2017-11-26        0.04  United Kingdom        15721
# 506918   2017-11-26        0.04  United Kingdom        17379
# 523461   2017-12-02        0.04  United Kingdom        14456
# 525404   2017-12-03        0.04  United Kingdom        15053
#
# [66 rows x 8 columns]

# %%
# investigating prices too high
df_raw_3[df_raw_3['unit_price']>500].sample(10)
# Out:
#        invoice_no stock_code     description  quantity invoice_date  \
# 188277     553018          M          Manual         1   2017-05-10
# 264976     560187       POST         POSTAGE         1   2017-07-13
# 429248    C573549  AMAZONFEE      AMAZON FEE        -1   2017-10-29
# 36461      539451        DOT  DOTCOM POSTAGE         1   2016-12-15
# 88210     C543789          M          Manual        -1   2017-02-09
# 268477     560431          M          Manual         1   2017-07-16
# 45622     C540271          M          Manual        -1   2017-01-04
# 511104     579471        DOT  DOTCOM POSTAGE         1   2017-11-27
# 268027    C560372          M          Manual        -1   2017-07-16
# 422376     573080          M          Manual         1   2017-10-25
#
#         unit_price         country  customer_id
# 188277      557.72        Portugal        12757
# 264976      550.94          Canada        17444
# 429248     5942.57  United Kingdom        22217
# 36461       662.14  United Kingdom        19244
# 88210       856.48  United Kingdom        17450
# 268477      611.86  United Kingdom        21267
# 45622      1126.00           Spain        12503
# 511104      892.50  United Kingdom        22582
# 268027     4287.63  United Kingdom        17448
# 422376     4161.06          France        12536

# %% [markdown]
# ### 3.1.2. quantity
# - All invoices with string in the description have negative quantity. It will be considered as returns
# - There some high suspect high quantities, however doesn't seem to be errors

# %%
# check samples
df_raw_3[df_raw_3['quantity']<-9000]
# Out:
#        invoice_no stock_code                          description  quantity  \
# 4287      C536757      84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 61624     C541433      23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225528     556687      23003         Printing smudges/thrown away     -9058
# 225529     556690      23005         printing smudges/thrown away     -9600
# 225530     556691      23005         printing smudges/thrown away     -9600
# 540422    C581484      23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#        invoice_date  unit_price         country  customer_id
# 4287     2016-11-30        0.03  United Kingdom        15838
# 61624    2017-01-16        1.04  United Kingdom        12346
# 225528   2017-06-12        0.00  United Kingdom        20913
# 225529   2017-06-12        0.00  United Kingdom        20914
# 225530   2017-06-12        0.00  United Kingdom        20915
# 540422   2017-12-07        2.08  United Kingdom        16446

# %%
# investigating extreme values
df_raw_3[(df_raw_3['quantity']<-9000)]
# Out:
#        invoice_no stock_code                          description  quantity  \
# 4287      C536757      84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 61624     C541433      23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225528     556687      23003         Printing smudges/thrown away     -9058
# 225529     556690      23005         printing smudges/thrown away     -9600
# 225530     556691      23005         printing smudges/thrown away     -9600
# 540422    C581484      23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#        invoice_date  unit_price         country  customer_id
# 4287     2016-11-30        0.03  United Kingdom        15838
# 61624    2017-01-16        1.04  United Kingdom        12346
# 225528   2017-06-12        0.00  United Kingdom        20913
# 225529   2017-06-12        0.00  United Kingdom        20914
# 225530   2017-06-12        0.00  United Kingdom        20915
# 540422   2017-12-07        2.08  United Kingdom        16446

# %%
# investiganting if invoice_no has any relation with negative values
df_invoice_str = df_raw_3.loc[df_raw_3['invoice_no'].apply(lambda x: bool(re.search('[^0-9]+', x))),:]

# df_invoice_str[df_invoice_str['quantity']>=0]
# df_aux = df_raw_3[df_raw_3['quantity']>0]
# df_aux = df_aux.astype({'invoice_no':'int64'})

# %%
# df_raw_3[(df_raw_3['customer_id']==13256)].sort_values('quantity')

# %% [markdown]
# ### 3.1.3. stock_code
# Exclude stock_codes = ['POST', 'D', 'M', 'PADS', 'DOT', 'CRUK', 'BANK CHARGES'] (do not seem to be relevant to the model

# %%
df_raw_3.loc[df_raw_3['stock_code'].apply( lambda x: bool( re.search( '^[a-zA-Z]+$', x ) ) ), 'stock_code'].unique()
# POST - seems to be cost of exportation to another coutry
# D - discount
# M - seems to be some kind of manual adjustment
# PADS - seems to be some kind of protection that goes in the package
# DOTCOM - ??
# CRUK - ??

# list created using libreoffice calc
exclude_stock_codes = [
'AMAZONFEE',
'B',
'BANK CHARGES',
'C2',
'CRUK',
'D',
'DCGS0003',
'DCGS0004',
'DCGS0055',
'DCGS0057',
'DCGS0066P',
'DCGS0067',
'DCGS0068',
'DCGS0069',
'DCGS0070',
'DCGS0071',
'DCGS0072',
'DCGS0073',
'DCGS0074',
'DCGS0076',
'DCGSSBOY',
'DCGSSGIRL',
'DOT',
'gift_0001_10',
'gift_0001_20',
'gift_0001_30',
'gift_0001_40',
'gift_0001_50',
'M',
'm',
'PADS',
'POST',
'S']

# %% [markdown]
# ### 3.1.4. country
# Do not remove yet

# %%
df_raw_3['country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df_raw_3['country'].value_counts(normalize=True).head()
# Out:
# United Kingdom    0.914320
# Germany           0.017521
# France            0.015790
# EIRE              0.015124
# Spain             0.004674
# Name: country, dtype: float64

# %%
df_raw_3[df_raw_3['country']=='European Community']
# Out:
#        invoice_no stock_code                          description  quantity  \
# 168149     551013      22839      3 TIER CAKE TIN GREEN AND CREAM         1
# 168150     551013      22840           ROUND CAKE TIN VINTAGE RED         2
# 168151     551013      22841         ROUND CAKE TIN VINTAGE GREEN         2
# 168152     551013      22457      NATURAL SLATE HEART CHALKBOARD          6
# 168153     551013      22314          OFFICE MUG WARMER CHOC+BLUE         6
# ...           ...        ...                                  ...       ...
# 273232     560783      21098                CHRISTMAS TOILET ROLL        12
# 273233     560783     72807C  SET/3 VANILLA SCENTED CANDLE IN BOX        12
# 273234     560783     85036B   CHOCOLATE 1 WICK MORRIS BOX CANDLE        12
# 273235     560783     85035C        ROSE 3 WICK MORRIS BOX CANDLE         8
# 273236     560783       POST                              POSTAGE         4
#
#        invoice_date  unit_price             country  customer_id
# 168149   2017-04-24       14.95  European Community        15108
# 168150   2017-04-24        7.95  European Community        15108
# 168151   2017-04-24        7.95  European Community        15108
# 168152   2017-04-24        2.95  European Community        15108
# 168153   2017-04-24        2.95  European Community        15108
# ...             ...         ...                 ...          ...
# 273232   2017-07-19        1.25  European Community        15108
# 273233   2017-07-19        4.25  European Community        15108
# 273234   2017-07-19        4.25  European Community        15108
# 273235   2017-07-19        4.25  European Community        15108
# 273236   2017-07-19       15.00  European Community        15108
#
# [61 rows x 8 columns]

# %% [markdown]
# ## 3.2. Data Filtering

# %%
# unit price
df_raw_3 = df_raw_3.loc[df_raw_3['unit_price']>0.01,:]

# stock code
df_raw_3 = df_raw_3[~df_raw_3['stock_code'].isin(exclude_stock_codes)]

# quantity
df_raw_returns = df_raw_3.loc[df_raw_3['quantity']<0, :]
df_raw_purchases = df_raw_3.loc[df_raw_3['quantity']>=0, :]

# %% [markdown]
# # 4.0. FEATURE ENGINEERING

# %%
df_raw_4 = df_raw_3.copy()

# %% [markdown]
# ## 4.1. Features Creation

# %%
# separate unique customers
df_ref = df_raw_4.drop(['invoice_no', 'stock_code', 'description', 'quantity', 'invoice_date',
       'unit_price', 'country'], axis=1).drop_duplicates(ignore_index=True)

# %% [markdown]
# ### 4.1.1. Gross Revenue - total money spent by customer

# %%
# calculated from total invoices (returns are subtracted from gross revenue)
df_raw_4['gross_revenue'] = df_raw_4['quantity']*df_raw_4['unit_price']
df_gross_revenue = df_raw_4[['customer_id', 'gross_revenue']].groupby('customer_id').sum().reset_index()
df_ref = pd.merge(df_ref, df_gross_revenue, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id      0
# gross_revenue    0
# dtype: int64

# %% [markdown]
# ### 4.1.2. Average Ticket Value - average amount of money spent by customer on each transaction

# %%
df_avg_ticket = (df_raw_4[['customer_id', 'invoice_no', 'gross_revenue']].groupby('customer_id')
                                                                         .agg(n_invoices=('invoice_no', 'nunique'),
                                                                              sum_revenue=('gross_revenue', 'sum'))
                                                                         .reset_index())
df_avg_ticket['avg_ticket'] = df_avg_ticket['sum_revenue']/df_avg_ticket['n_invoices']
df_ref = pd.merge(df_ref, df_avg_ticket[['customer_id', 'avg_ticket']], on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id      0
# gross_revenue    0
# avg_ticket       0
# dtype: int64

# %% [markdown]
# ### 4.1.3. Recency - number of days since last purchase

# %%
# recency - last day of purchase
# calculated from dataframe with only purchases
df_recency = df_raw_purchases.loc[:, ['customer_id', 'invoice_date']].groupby( 'customer_id' ).max().reset_index()
df_recency['recency'] = (df_raw_4['invoice_date'].max()-df_recency['invoice_date']).dt.days+1
df_recency = df_recency[['customer_id', 'recency']]
df_ref = pd.merge(df_ref, df_recency, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id       0
# gross_revenue     0
# avg_ticket        0
# recency          67
# dtype: int64

# %% [markdown]
# ### 4.1.4. Frequency - number of purchases in last 365 days

# %%
# frequency - number of purchases in last 365 days
dd = datetime.timedelta(days=365)
df_frequency = df_raw_purchases[df_raw_purchases['invoice_date']>=(df_raw_purchases['invoice_date'].max() - dd)][['invoice_no', 'customer_id']].drop_duplicates().groupby('customer_id').count().reset_index().rename(columns={'invoice_no':'frequency'})
df_ref = pd.merge(df_ref, df_frequency, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue      0
# avg_ticket         0
# recency           67
# frequency        177
# dtype: int64

# %% [markdown]
# ### 4.1.5. Quantity of Returns - number of invoices with negative quantity

# %%
df_returns = (df_raw_returns[['customer_id', 'invoice_no']].drop_duplicates()
                                                           .groupby('customer_id')
                                                           .count()
                                                           .reset_index()
                                                           .rename(columns={'invoice_no':'qty_returns'}))
df_ref = pd.merge(df_ref, df_returns, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id         0
# gross_revenue       0
# avg_ticket          0
# recency            67
# frequency         177
# qty_returns      4199
# dtype: int64

# %% [markdown]
# ### 4.1.6. Amount Returned

# %%
df_raw_returns['amount_returned'] = df_raw_returns['quantity']*df_raw_returns['unit_price']*-1
df_amount_returned = df_raw_returns[['customer_id', 'amount_returned']].groupby('customer_id').sum().reset_index()
df_ref = pd.merge(df_ref, df_amount_returned, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id           0
# gross_revenue         0
# avg_ticket            0
# recency              67
# frequency           177
# qty_returns        4199
# amount_returned    4199
# dtype: int64

# %% [markdown]
# ### 4.1.7. Quantity of Products

# %%
df_quantity = (df_raw_4[['customer_id','quantity']].groupby('customer_id')
                                                           .sum()
                                                           .reset_index()
                                                           .rename(columns={'quantity': 'qty_items'}))
df_ref = pd.merge(df_ref, df_quantity, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id           0
# gross_revenue         0
# avg_ticket            0
# recency              67
# frequency           177
# qty_returns        4199
# amount_returned    4199
# qty_items             0
# dtype: int64

# %% [markdown]
# ### 4.1.8. Average Basket Size - quantity of products / total of invoices

# %%
df_avg_bs = (df_raw_4[['customer_id', 'invoice_no', 'quantity']].groupby('customer_id')
                                                                        .agg(n_purchases=('invoice_no', 'nunique'),
                                                                             n_products=('quantity', 'sum'))
                                                                        .reset_index())
df_avg_bs['avg_basket_size'] = df_avg_bs['n_products']/df_avg_bs['n_purchases']
df_ref = pd.merge(df_ref, df_avg_bs[['customer_id', 'avg_basket_size']], on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id           0
# gross_revenue         0
# avg_ticket            0
# recency              67
# frequency           177
# qty_returns        4199
# amount_returned    4199
# qty_items             0
# avg_basket_size       0
# dtype: int64

# %% [markdown]
# ### 4.1.9. Assortment- quantity of distinct items purchased

# %%
df_assortment = (df_raw_purchases[['customer_id', 'stock_code']].drop_duplicates()
                                                                .groupby('customer_id')
                                                                .count()
                                                                .reset_index()
                                                                .rename(columns={'stock_code': 'assortment'}))
df_ref = pd.merge(df_ref, df_assortment, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id           0
# gross_revenue         0
# avg_ticket            0
# recency              67
# frequency           177
# qty_returns        4199
# amount_returned    4199
# qty_items             0
# avg_basket_size       0
# assortment           67
# dtype: int64

# %% [markdown]
# ## 4.2. Check NA and DTypes after Feature Creation

# %%
# NANs
df_ref.isna().sum()
# Out:
# customer_id           0
# gross_revenue         0
# avg_ticket            0
# recency              67
# frequency           177
# qty_returns        4199
# amount_returned    4199
# qty_items             0
# avg_basket_size       0
# assortment           67
# dtype: int64

# %%
# DTypes
df_ref.dtypes
# Out:
# customer_id          int64
# gross_revenue      float64
# avg_ticket         float64
# recency            float64
# frequency          float64
# qty_returns        float64
# amount_returned    float64
# qty_items            int64
# avg_basket_size    float64
# assortment         float64
# dtype: object

# %% [markdown]
# ### 4.2.1. Replace NA in df_ref

# %%
# nan values were assigned to customers with 0 purchases in the last 365 days
df_ref['frequency'] = df_ref['frequency'].fillna(0)

# nan values were assigned to customers wih 0 returns
df_ref['qty_returns'] = df_ref['qty_returns'].fillna(0)
df_ref['amount_returned'] = df_ref['amount_returned'].fillna(0)

# drop NA for remaining attributes
df_ref = df_ref.dropna()

# %%
# change dtypes
df_ref = df_ref.astype({'recency':'int64', 
                        'frequency': 'int64', 
                        'qty_returns':'int64',
                        'qty_items': 'int64',
                        'assortment':'int64'})

# %% [markdown]
# # 5.0. EDA (EXPLORATORY DATA ANALYSIS)

# %%
df_ref_5 = df_ref.copy()

# %% [markdown]
# ## 5.1. Univariate Analysis

# %%
# pd_profile = ProfileReport(df_ref_5)
# pd_profile.to_file('output_df_ref_5_03R.html')

# %% [markdown]
# ### 5.1.1. Gross Revenue
# - OK

# %%
df_ref_5[df_ref_5['gross_revenue']>180000]
# Out:
#       customer_id  gross_revenue   avg_ticket  recency  frequency  \
# 433         17450      189735.53  3872.153673        9         44
# 490         18102      259657.30  4327.621667        1         57
# 1014        14646      278778.02  3818.876986        2         72
#
#       qty_returns  amount_returned  qty_items  avg_basket_size  assortment
# 433             3          4815.26      69041      1409.000000         124
# 490             0             0.00      64124      1068.733333         150
# 1014            1           360.00     196556      2692.547945         699

# %%
df_raw_4[df_raw_4['customer_id']==18102].sample(10)
# Out:
#        invoice_no stock_code                          description  quantity  \
# 343150     566936      21524       DOORMAT SPOTTY HOME SWEET HOME       100
# 192727     553471      22061  LARGE CAKE STAND  HANGING STRAWBERY        32
# 411193     572196      23133     LARGE IVORY HEART WALL ORGANISER       120
# 354116     567860      22839      3 TIER CAKE TIN GREEN AND CREAM         4
# 540061     581457      23543                  WALL ART KEEP CALM        698
# 439193     574363      23529                 WALL ART DOLLY GIRL        120
# 411201     572196      23531                   WALL ART BIG LOVE        120
# 540060     581457      22189              CREAM HEART CARD HOLDER       324
# 540068     581457      23526                WALL ART DOG LICENCE        126
# 373022     569257      23533               WALL ART GARDEN HAVEN         36
#
#        invoice_date  unit_price         country  customer_id  gross_revenue
# 343150   2017-09-13        4.58  United Kingdom        18102         458.00
# 192727   2017-05-15        6.79  United Kingdom        18102         217.28
# 411193   2017-10-19        5.66  United Kingdom        18102         679.20
# 354116   2017-09-20        9.98  United Kingdom        18102          39.92
# 540061   2017-12-06        4.15  United Kingdom        18102        2896.70
# 439193   2017-11-02        2.66  United Kingdom        18102         319.20
# 411201   2017-10-19        4.77  United Kingdom        18102         572.40
# 540060   2017-12-06        3.39  United Kingdom        18102        1098.36
# 540068   2017-12-06        3.90  United Kingdom        18102         491.40
# 373022   2017-10-01        3.88  United Kingdom        18102         139.68

# %% [markdown]
# ### 5.1.2. Average Ticket
# - OK

# %%
df_ref_5[df_ref_5['avg_ticket']>5000]
# Out:
#       customer_id  gross_revenue    avg_ticket  recency  frequency  \
# 97          19014        6308.16   6308.160000      374          0
# 235         19027        6369.56   6369.560000      372          0
# 257         19033       10661.69  10661.690000      372          0
# 353         19069        6471.71   6471.710000      369          0
# 355         19070        6719.61   6719.610000      369          0
# 426         19084        7272.41   7272.410000      369          0
# 478         19109        5457.72   5457.720000      368          0
# 479         19111       11540.34  11540.340000      368          0
# 556         19125        5344.29   5344.290000      367          0
# 632         19154        6366.58   6366.580000      366          1
# 679         19188        5424.59   5424.590000      365          1
# 712         19195        5692.33   5692.330000      365          1
# 713         19196       12633.67  12633.670000      365          1
# 838         19217       12681.58  12681.580000      361          1
# 988         19241        5142.94   5142.940000      358          1
# 1071        19296       18745.86  18745.860000      354          1
# 1147        12415      123638.18   5151.590833       25         20
# 1260        15749       21535.90   5383.975000      236          3
# 1268        19390        5032.29   5032.290000      333          1
# 2216        19787        5307.65   5307.650000      278          1
# 2630        20055       21389.60  21389.600000      256          1
# 3622        15098       39619.50   9904.875000      183          3
# 3845        21081        7847.43   7847.430000      164          1
# 4265        21484       12172.09  12172.090000      121          1
# 4354        21542        5234.73   5234.730000      108          1
# 5251        22221       14838.86  14838.860000       40          1
# 5341        12357        6207.67   6207.670000       34          1
# 5354        22312       52940.94  52940.940000       33          1
# 5468        22383       50653.91  50653.910000       26          1
# 5500        22436        5370.14   5370.140000       24          1
# 5516        22458        7043.69   7043.690000       22          1
# 5531        22476        5378.45   5378.450000       22          1
# 5575        22493        6167.53   6167.530000       18          1
# 5592        22517        5848.71   5848.710000       17          1
# 5598        22527        5422.26   5422.260000       16          1
# 5618        22555        6778.73   6778.730000       15          1
# 5629        22560        5455.58   5455.580000       15          1
# 5673        22584        5072.32   5072.320000       11          1
# 5688        22611        5880.64   5880.640000       10          1
# 5695        22619        6179.65   6179.650000        9          1
# 5707        22629        5933.15   5933.150000        8          1
# 5719        22655        5377.81   5377.810000        5          1
# 5733        22663        7848.73   7848.730000        5          1
# 5734        22664        6024.97   6024.970000        5          1
# 5747        22671        5377.65   5377.650000        4          1
# 5757        22695        6075.62   6075.620000        2          1
# 5758        22696        7150.07   7150.070000        2          1
# 5767        22706        5699.00   5699.000000        2          1
# 5768        22707        6756.06   6756.060000        1          1
#
#       qty_returns  amount_returned  qty_items  avg_basket_size  assortment
# 97              0             0.00       1477      1477.000000         589
# 235             0             0.00       1640      1640.000000         585
# 257             0             0.00       1834      1834.000000         145
# 353             0             0.00       1607      1607.000000         594
# 355             0             0.00       1810      1810.000000         567
# 426             0             0.00       1868      1868.000000         673
# 478             0             0.00       1447      1447.000000         600
# 479             0             0.00       2200      2200.000000         148
# 556             0             0.00       1483      1483.000000         588
# 632             0             0.00       1640      1640.000000         646
# 679             0             0.00       1305      1305.000000         530
# 712             0             0.00       1502      1502.000000         605
# 713             0             0.00       2229      2229.000000         140
# 838             0             0.00       2150      2150.000000         148
# 988             0             0.00       1309      1309.000000         515
# 1071            0             0.00       2853      2853.000000         153
# 1147            4           926.35      76946      3206.083333         443
# 1260            1         22998.40       9014      2253.500000           5
# 1268            0             0.00       1258      1258.000000         126
# 2216            0             0.00       1365      1365.000000         119
# 2630            0             0.00       5963      5963.000000         138
# 3622            1           297.00         61        15.250000           1
# 3845            0             0.00       4136      4136.000000         703
# 4265            0             0.00       2500      2500.000000         352
# 4354            0             0.00       1191      1191.000000          82
# 5251            0             0.00       5196      5196.000000        1108
# 5341            0             0.00       2708      2708.000000         131
# 5354            0             0.00      14149     14149.000000         101
# 5468            0             0.00      13956     13956.000000          99
# 5500            0             0.00       1687      1687.000000         584
# 5516            0             0.00       1457      1457.000000          86
# 5531            0             0.00       1620      1620.000000         560
# 5575            0             0.00       1242      1242.000000          78
# 5592            0             0.00       1007      1007.000000         281
# 5598            0             0.00       1602      1602.000000         621
# 5618            0             0.00       1402      1402.000000          74
# 5629            0             0.00        912       912.000000         246
# 5673            0             0.00       1516      1516.000000         577
# 5688            0             0.00       1762      1762.000000         686
# 5695            0             0.00       1986      1986.000000         643
# 5707            0             0.00       1871      1871.000000         649
# 5719            0             0.00        947       947.000000         270
# 5733            0             0.00       2455      2455.000000         720
# 5734            0             0.00       1857      1857.000000         660
# 5747            0             0.00       1650      1650.000000         628
# 5757            0             0.00       1851      1851.000000         674
# 5758            0             0.00       2150      2150.000000         748
# 5767            0             0.00       1747      1747.000000         634
# 5768            0             0.00       2010      2010.000000         730

# %%
df_raw_4[df_raw_4['customer_id']==15098]
# Out:
#        invoice_no stock_code                     description  quantity  \
# 222670     556442      22502      PICNIC BASKET WICKER SMALL        60
# 222680     556444      22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682     556446      22502  PICNIC BASKET WICKER 60 PIECES         1
# 222692    C556448      22502      PICNIC BASKET WICKER SMALL       -60
#
#        invoice_date  unit_price         country  customer_id  gross_revenue
# 222670   2017-06-08        4.95  United Kingdom        15098          297.0
# 222680   2017-06-08      649.50  United Kingdom        15098        38970.0
# 222682   2017-06-08      649.50  United Kingdom        15098          649.5
# 222692   2017-06-08        4.95  United Kingdom        15098         -297.0

# %% [markdown]
# ### 5.1.3. Frequency
# - OK

# %%
df_ref_5[df_ref_5['frequency']>180]
# Out:
#     customer_id  gross_revenue  avg_ticket  recency  frequency  qty_returns  \
# 47        12748       30486.53  140.490922        1        192           11
# 66        14911      128882.13  532.570785        2        191           44
#
#     amount_returned  qty_items  avg_basket_size  assortment
# 47          1830.79      23976       110.488479        1766
# 66          7393.59      76848       317.553719        1785

# %%
df_raw_4[df_raw_4['customer_id']==14911].sample(10)
# Out:
#        invoice_no stock_code                          description  quantity  \
# 482585     577479      21428  SET3 BOOK BOX GREEN GINGHAM FLOWER         12
# 144856     548858      22780       LIGHT GARLAND BUTTERFILES PINK         4
# 200532     554139      22483              RED GINGHAM TEDDY BEAR          6
# 488741     577850      22578   WOODEN STAR CHRISTMAS SCANDINAVIAN        24
# 505872     579102      22197                       POPCORN HOLDER        12
# 236165     557742      23166       MEDIUM CERAMIC TOP STORAGE JAR        12
# 190665     553203      22798     ANTIQUE GLASS DRESSING TABLE POT         8
# 71863      542216     16156L                       WRAP, CAROUSEL        25
# 37632      539473      22189              CREAM HEART CARD HOLDER         8
# 365157     568698      22738            RIBBON REEL SNOWY VILLAGE        10
#
#        invoice_date  unit_price country  customer_id  gross_revenue
# 482585   2017-11-18        4.25    EIRE        14911          51.00
# 144856   2017-04-02        4.25    EIRE        14911          17.00
# 200532   2017-05-21        2.95    EIRE        14911          17.70
# 488741   2017-11-20        0.29    EIRE        14911           6.96
# 505872   2017-11-26        0.85    EIRE        14911          10.20
# 236165   2017-06-20        1.25    EIRE        14911          15.00
# 190665   2017-05-13        2.95    EIRE        14911          23.60
# 71863    2017-01-24        0.42    EIRE        14911          10.50
# 37632    2016-12-17        3.95    EIRE        14911          31.60
# 365157   2017-09-26        1.65    EIRE        14911          16.50

# %% [markdown]
# ### 5.1.4. Quantity of Returns
# - OK

# %%
df_ref_5[df_ref_5['qty_returns']>30]
# Out:
#     customer_id  gross_revenue  avg_ticket  recency  frequency  qty_returns  \
# 66        14911      128882.13  532.570785        2        191           44
# 68        17841       40333.22  238.658107        2        121           45
# 96        14606       11567.10   92.536800        2         87           35
#
#     amount_returned  qty_items  avg_basket_size  assortment
# 66          7393.59      76848       317.553719        1785
# 68           634.50      22850       135.207101        1322
# 96           439.55       5969        47.752000         816

# %%
df_raw_4[df_raw_4['customer_id']==17841].sample(10)
# Out:
#        invoice_no stock_code                          description  quantity  \
# 218608     556056      22041         RECORD FRAME 7" SINGLE SIZE          1
# 214024     555562     47566B               TEA TIME PARTY BUNTING         1
# 321269     565141      21154            RED RETROSPOT OVEN GLOVE          2
# 393236     570818      20711                      JUMBO BAG TOYS          1
# 183006     552640      22722    SET OF 6 SPICE TINS PANTRY DESIGN         1
# 428671     573496      22665    RECIPE BOX BLUE SKETCHBOOK DESIGN         1
# 280673     561485     84519A      TOMATO CHARLIE+LOLA COASTER SET         2
# 479675     577174     72800E  4 IVORY DINNER CANDLES SILVER FLOCK         2
# 257556     559535      21672   WHITE SPOT RED CERAMIC DRAWER KNOB         3
# 434243     574034      23368    SET 12 COLOUR PENCILS DOLLY GIRL          1
#
#        invoice_date  unit_price         country  customer_id  gross_revenue
# 218608   2017-06-06        2.55  United Kingdom        17841           2.55
# 214024   2017-06-03        4.95  United Kingdom        17841           4.95
# 321269   2017-08-30        1.25  United Kingdom        17841           2.50
# 393236   2017-10-10        2.08  United Kingdom        17841           2.08
# 183006   2017-05-08        3.95  United Kingdom        17841           3.95
# 428671   2017-10-29        2.95  United Kingdom        17841           2.95
# 280673   2017-07-25        1.25  United Kingdom        17841           2.50
# 479675   2017-11-16        2.55  United Kingdom        17841           5.10
# 257556   2017-07-08        1.25  United Kingdom        17841           3.75
# 434243   2017-10-31        0.65  United Kingdom        17841           0.65

# %% [markdown]
# ### 5.1.5. Amount Returned
# - OK

# %%
df_ref_5[df_ref_5['amount_returned']>50000]
# Out:
#       customer_id  gross_revenue  avg_ticket  recency  frequency  qty_returns  \
# 1379        12346            0.0    0.000000      326          1            1
# 3328        16446            2.9    0.966667        1          2            1
#
#       amount_returned  qty_items  avg_basket_size  assortment
# 1379          77183.6          0         0.000000           1
# 3328         168469.6          2         0.666667           3

# %%
df_raw_4[df_raw_4['customer_id']==16446]
# Out:
#        invoice_no stock_code                  description  quantity  \
# 194354     553573      22980       PANTRY SCRUBBING BRUSH         1
# 194355     553573      22982          PANTRY PASTRY BRUSH         1
# 540421     581483      23843  PAPER CRAFT , LITTLE BIRDIE     80995
# 540422    C581484      23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#        invoice_date  unit_price         country  customer_id  gross_revenue
# 194354   2017-05-16        1.65  United Kingdom        16446           1.65
# 194355   2017-05-16        1.25  United Kingdom        16446           1.25
# 540421   2017-12-07        2.08  United Kingdom        16446      168469.60
# 540422   2017-12-07        2.08  United Kingdom        16446     -168469.60

# %% [markdown]
# ### 5.1.6. Quantity of Items
# - Change method of calculation to sum negative values of returns, so we have qty of items that was sold and not returned - **DONE**
# - **OBS**: filter values <= 0

# %%
# df_ref_5[df_ref_5['qty_items']>50000].sort_values('qty_items', ascending=False)
df_ref_5[df_ref_5['qty_items']<=0]
# Out:
#       customer_id  gross_revenue    avg_ticket  recency  frequency  \
# 16          17548  -1.414800e+02 -4.716000e+01      234          1
# 132         16546  -9.593000e+01 -3.197667e+01      291          1
# 1233        13672   0.000000e+00  0.000000e+00      302          2
# 1379        12346   0.000000e+00  0.000000e+00      326          1
# 3114        13762   3.552714e-15  1.776357e-15      219          1
# 4145        18268   0.000000e+00  0.000000e+00      135          1
# 4579        14557   0.000000e+00  0.000000e+00       86          1
# 4594        16878   0.000000e+00  0.000000e+00       85          1
# 4780        13364   0.000000e+00  0.000000e+00       72          1
# 4886        14792   0.000000e+00  0.000000e+00       64          1
# 4946        12607   3.552714e-15  1.776357e-15       61          1
# 5012        12454   5.684342e-14  2.842171e-14       57          1
# 5394        18274   1.776357e-15  8.881784e-16       31          1
# 5700        12558   1.065814e-14  5.329071e-15        8          1
#
#       qty_returns  amount_returned  qty_items  avg_basket_size  assortment
# 16              2           244.78       -132            -44.0           5
# 132             1           883.08       -303           -101.0          25
# 1233            3           186.39          0              0.0           4
# 1379            1         77183.60          0              0.0           1
# 3114            1           306.72          0              0.0           7
# 4145            1            25.50          0              0.0           1
# 4579            1           788.38          0              0.0          16
# 4594            1            13.30          0              0.0           3
# 4780            1           134.96          0              0.0          10
# 4886            1             6.20          0              0.0           2
# 4946            1          1579.51          0              0.0         101
# 5012            1          3528.34          0              0.0          15
# 5394            1           175.92          0              0.0          11
# 5700            1           269.96          0              0.0          11

# %%
df_raw_4[df_raw_4['customer_id']==12558]
# Out:
#        invoice_no stock_code                        description  quantity  \
# 519634     580158      22712                   CARD DOLLY GIRL         12
# 519635     580158      23344          JUMBO BAG 50'S CHRISTMAS         10
# 519636     580158     85099B            JUMBO BAG RED RETROSPOT        10
# 519637     580158      23209           LUNCH BAG VINTAGE DOILY         20
# 519638     580158     79191C        RETRO PLASTIC ELEPHANT TRAY        24
# 519639     580158      23392       SPACEBOY ROCKET LOLLY MAKERS        24
# 519640     580158      84828  JUNGLE POPSICLES ICE LOLLY MOULDS        24
# 519641     580158      23158        SET OF 5 LUCKY CAT MAGNETS         36
# 519642     580158      21507            ELEPHANT BIRTHDAY CARD         12
# 519643     580158      21508            VINTAGE KID DOLLY CARD         12
# 519644     580158      22027            TEA PARTY BIRTHDAY CARD        12
# 536916    C581229     85099B            JUMBO BAG RED RETROSPOT       -10
# 536917    C581229      84828  JUNGLE POPSICLES ICE LOLLY MOULDS       -24
# 536918    C581229     79191C        RETRO PLASTIC ELEPHANT TRAY       -24
# 536919    C581229      23392       SPACEBOY ROCKET LOLLY MAKERS       -24
# 536920    C581229      23344          JUMBO BAG 50'S CHRISTMAS        -10
# 536921    C581229      23209           LUNCH BAG VINTAGE DOILY        -20
# 536922    C581229      23158        SET OF 5 LUCKY CAT MAGNETS        -36
# 536923    C581229      22712                   CARD DOLLY GIRL        -12
# 536924    C581229      22027            TEA PARTY BIRTHDAY CARD       -12
# 536925    C581229      21508            VINTAGE KID DOLLY CARD        -12
# 536926    C581229      21507            ELEPHANT BIRTHDAY CARD        -12
#
#        invoice_date  unit_price country  customer_id  gross_revenue
# 519634   2017-11-30        0.42     USA        12558           5.04
# 519635   2017-11-30        2.08     USA        12558          20.80
# 519636   2017-11-30        2.08     USA        12558          20.80
# 519637   2017-11-30        1.65     USA        12558          33.00
# 519638   2017-11-30        0.85     USA        12558          20.40
# 519639   2017-11-30        2.08     USA        12558          49.92
# 519640   2017-11-30        1.25     USA        12558          30.00
# 519641   2017-11-30        2.08     USA        12558          74.88
# 519642   2017-11-30        0.42     USA        12558           5.04
# 519643   2017-11-30        0.42     USA        12558           5.04
# 519644   2017-11-30        0.42     USA        12558           5.04
# 536916   2017-12-06        2.08     USA        12558         -20.80
# 536917   2017-12-06        1.25     USA        12558         -30.00
# 536918   2017-12-06        0.85     USA        12558         -20.40
# 536919   2017-12-06        2.08     USA        12558         -49.92
# 536920   2017-12-06        2.08     USA        12558         -20.80
# 536921   2017-12-06        1.65     USA        12558         -33.00
# 536922   2017-12-06        2.08     USA        12558         -74.88
# 536923   2017-12-06        0.42     USA        12558          -5.04
# 536924   2017-12-06        0.42     USA        12558          -5.04
# 536925   2017-12-06        0.42     USA        12558          -5.04
# 536926   2017-12-06        0.42     USA        12558          -5.04

# %% [markdown]
# ### 5.1.7. Average Basket Size
# - Change method of calculation to sum negative values of returns, so we have qty of items that was sold and not returned - **DONE**
# - **OBS**: filter values <= 0

# %%
# df_ref_5[df_ref_5['avg_basket_size']>5000].sort_values('avg_basket_size', ascending=False)
df_ref_5[df_ref_5['avg_basket_size']<=0]
# Out:
#       customer_id  gross_revenue    avg_ticket  recency  frequency  \
# 16          17548  -1.414800e+02 -4.716000e+01      234          1
# 132         16546  -9.593000e+01 -3.197667e+01      291          1
# 1233        13672   0.000000e+00  0.000000e+00      302          2
# 1379        12346   0.000000e+00  0.000000e+00      326          1
# 3114        13762   3.552714e-15  1.776357e-15      219          1
# 4145        18268   0.000000e+00  0.000000e+00      135          1
# 4579        14557   0.000000e+00  0.000000e+00       86          1
# 4594        16878   0.000000e+00  0.000000e+00       85          1
# 4780        13364   0.000000e+00  0.000000e+00       72          1
# 4886        14792   0.000000e+00  0.000000e+00       64          1
# 4946        12607   3.552714e-15  1.776357e-15       61          1
# 5012        12454   5.684342e-14  2.842171e-14       57          1
# 5394        18274   1.776357e-15  8.881784e-16       31          1
# 5700        12558   1.065814e-14  5.329071e-15        8          1
#
#       qty_returns  amount_returned  qty_items  avg_basket_size  assortment
# 16              2           244.78       -132            -44.0           5
# 132             1           883.08       -303           -101.0          25
# 1233            3           186.39          0              0.0           4
# 1379            1         77183.60          0              0.0           1
# 3114            1           306.72          0              0.0           7
# 4145            1            25.50          0              0.0           1
# 4579            1           788.38          0              0.0          16
# 4594            1            13.30          0              0.0           3
# 4780            1           134.96          0              0.0          10
# 4886            1             6.20          0              0.0           2
# 4946            1          1579.51          0              0.0         101
# 5012            1          3528.34          0              0.0          15
# 5394            1           175.92          0              0.0          11
# 5700            1           269.96          0              0.0          11

# %%
df_raw_4[df_raw_4['customer_id']==18251]
# Out:
#        invoice_no stock_code                          description  quantity  \
# 339449     566595      21975       PACK OF 60 DINOSAUR CAKE CASES       600
# 339450     566595      21213          PACK OF 72 SKULL CAKE CASES       600
# 339451     566595      84992       72 SWEETHEART FAIRY CAKE CASES       600
# 339452     566595      84991          60 TEATIME FAIRY CAKE CASES       600
# 339453     566595      23340         VINTAGE CHRISTMAS CAKE FRILL       480
# 339454     566595      21212      PACK OF 72 RETROSPOT CAKE CASES       600
# 339455     566595      21977   PACK OF 60 PINK PAISLEY CAKE CASES       600
# 339456     566595      23378    PACK OF 12 50'S CHRISTMAS TISSUES       432
# 339457     566595      23380     PACK OF 12 VINTAGE DOILY TISSUES       432
# 339458     566595      23381     PACK OF 12 VINTAGE LEAF TISSUES        432
# 339459     566595      22094             RED RETROSPOT TISSUE BOX       360
# 339460     566595      22096      PINK PAISLEY SQUARE TISSUE BOX        432
# 339461     566595      22909  SET OF 20 VINTAGE CHRISTMAS NAPKINS       576
# 339462     566595      22950         36 DOILIES VINTAGE CHRISTMAS       288
# 339463     566595      22952      60 CAKE CASES VINTAGE CHRISTMAS       720
# 339464     566595      22138        BAKING SET 9 PIECE RETROSPOT         72
#
#        invoice_date  unit_price         country  customer_id  gross_revenue
# 339449   2017-09-11        0.42  United Kingdom        18251         252.00
# 339450   2017-09-11        0.42  United Kingdom        18251         252.00
# 339451   2017-09-11        0.42  United Kingdom        18251         252.00
# 339452   2017-09-11        0.42  United Kingdom        18251         252.00
# 339453   2017-09-11        1.45  United Kingdom        18251         696.00
# 339454   2017-09-11        0.42  United Kingdom        18251         252.00
# 339455   2017-09-11        0.42  United Kingdom        18251         252.00
# 339456   2017-09-11        0.32  United Kingdom        18251         138.24
# 339457   2017-09-11        0.32  United Kingdom        18251         138.24
# 339458   2017-09-11        0.32  United Kingdom        18251         138.24
# 339459   2017-09-11        0.39  United Kingdom        18251         140.40
# 339460   2017-09-11        0.39  United Kingdom        18251         168.48
# 339461   2017-09-11        0.72  United Kingdom        18251         414.72
# 339462   2017-09-11        1.25  United Kingdom        18251         360.00
# 339463   2017-09-11        0.42  United Kingdom        18251         302.40
# 339464   2017-09-11        4.25  United Kingdom        18251         306.00

# %% [markdown]
# ## 5.2. Bivariate Analysis

# %%
df_ref_52 = df_ref_5.drop(columns = 'customer_id')

# %%
plt.figure(figsize=(25, 12))
sns.pairplot(df_ref_52);

# %% [markdown]
# **Notes**
# - amount_returned has low variance
# - avg_basket_size seems to variate a lot like qty_items and assortment
# - qyt_returns and frequenvy
# - gross_revenue and avg_ticket

# %% [markdown]
# ## 5.3. Space Analysis

# %%
# selected features for analysis
cols_selected = ['gross_revenue', 'recency', 'frequency', 'qty_returns', 'qty_items', 'assortment']
df_ref_53 = df_ref_52[cols_selected]

# %%
mm = pp.MinMaxScaler()

df_ref_53['gross_revenue']   = mm.fit_transform(df_ref_53[['gross_revenue']])
# df_ref_53['avg_ticket']      = mm.fit_transform(df_ref_53[['avg_ticket']])
df_ref_53['recency']         = mm.fit_transform(df_ref_53[['recency']])
df_ref_53['frequency']       = mm.fit_transform(df_ref_53[['frequency']])
df_ref_53['qty_returns']     = mm.fit_transform(df_ref_53[['qty_returns']])
# df_ref_53['amount_returned'] = mm.fit_transform(df_ref_53[['amount_returned']])
df_ref_53['qty_items']       = mm.fit_transform(df_ref_53[['qty_items']])
#df_ref_53['avg_basket_size'] = mm.fit_transform(df_ref_53[['avg_basket_size']])
df_ref_53['assortment']      = mm.fit_transform(df_ref_53[['assortment']])

X = df_ref_53.copy()

# %% [markdown]
# ### 5.3.1. PCA

# %%
pca = dc.PCA(n_components=X.shape[1])

principal_components = pca.fit_transform(X)

# plot explained variables
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')

df_pca = pd.DataFrame(principal_components)

# %%
sns.scatterplot(x=0, y=1, data=df_pca);

# %% [markdown]
# ### 5.3.2. UMAP

# %%
reducer = umap.UMAP(random_state=42)
embedding = reducer.fit_transform(X)

# embedding
df_pca['embedding_x'] = embedding[:, 0]
df_pca['embedding_y'] = embedding[:, 1]

# plot UMAP
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_pca)
# Out:
# <AxesSubplot: xlabel='embedding_x', ylabel='embedding_y'>

# %% [markdown]
# ### 5.3.3. t-SNE

# %%
reducer = mn.TSNE(n_components=2, n_jobs=-1, random_state=42)
embedding = reducer.fit_transform(X)

# embedding
df_pca['embedding_x'] = embedding[:, 0]
df_pca['embedding_y'] = embedding[:, 1]

# plot t-SNE
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_pca);
# Out:
# /home/felipe/repos/insiders_clustering/insiders_env/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/felipe/repos/insiders_clustering/insiders_env/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ### 5.3.4. Tree-Based Embedding

# %%
# training dataset
X = df_ref_5[['recency', 'frequency', 'qty_returns', 'qty_items', 'assortment']]
y = df_ref_5['gross_revenue']

# model definition
rf_model = en.RandomForestRegressor(n_estimators=100, random_state=42)

# model training
rf_model.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# dataframe leafs
df_leaf = pd.DataFrame(rf_model.apply(X))

# reducer of dimensionality
reducer = umap.UMAP(random_state=42)
embedding = reducer.fit_transform(df_leaf)

# embedding
df_tree = pd.DataFrame()
df_tree['embedding_x'] = embedding[:, 0]
df_tree['embedding_y'] = embedding[:, 1]

# plot df_tree
sns.scatterplot(x='embedding_x', y='embedding_y', data=df_tree);

# %% [markdown]
# # 6.0. DATA PREPARATION

# %%
df_ref_6 = df_ref_5.copy()

# %%
ss = pp.MinMaxScaler()

df_ref_6['gross_revenue']   = mm.fit_transform(df_ref_6[['gross_revenue']])
df_ref_6['avg_ticket']      = mm.fit_transform(df_ref_6[['avg_ticket']])
df_ref_6['recency']         = mm.fit_transform(df_ref_6[['recency']])
df_ref_6['frequency']       = mm.fit_transform(df_ref_6[['frequency']])
df_ref_6['qty_returns']     = mm.fit_transform(df_ref_6[['qty_returns']])
df_ref_6['amount_returned'] = mm.fit_transform(df_ref_6[['amount_returned']])
df_ref_6['qty_items']       = mm.fit_transform(df_ref_6[['qty_items']])
df_ref_6['avg_basket_size'] = mm.fit_transform(df_ref_6[['avg_basket_size']])
df_ref_6['assortment']      = mm.fit_transform(df_ref_6[['assortment']])

# %% [markdown]
# # 7.0. FEATURE SELECTION

# %%
df_ref_7 = df_ref_6[['customer_id', 
                     'gross_revenue', 
                     'recency', 
                     'frequency', 
                     'qty_returns', 
                     'qty_items', 
                     'assortment']].copy()

# %% [markdown]
# # 8.0. HYPER-PARAMETER FINE TUNING

# %%
X = df_ref_7.drop(columns='customer_id')

# %%
# number of cluster to test
clusters = [2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ## 8.1. KMeans

# %%
kmeans_list = []
for k in clusters:
    # model definition
    kmeans_model = C.KMeans(n_clusters=k)
    
    # model training
    kmeans_model.fit(X)
    
    # model predict
    labels = kmeans_model.predict(X)
    
    # model performance
    sil = M.silhouette_score(X, labels, metric='euclidean')
    kmeans_list.append(sil)

# %%
plt.plot(clusters, kmeans_list, linestyle='--', marker='o', color='b')
plt.xlabel('x')
plt.ylabel('Silhouette Score')
plt.title('Silhoutte Score x K')
# Out:
# Text(0.5, 1.0, 'Silhoutte Score x K')

# %% [markdown]
# ## 8.2. GMM

# %%
gmm_list = []

for k in clusters:
    # model definition
    gmm_model = mx.GaussianMixture(n_components=k, n_init=10)
    
    # model training
    gmm_model.fit(X)
    
    # model predict
    labels = gmm_model.predict(X)
    
    # model performance
    sil = M.silhouette_score(X, labels, metric='euclidean')
    gmm_list.append(sil)

# %%
plt.plot(clusters, gmm_list, linestyle='--', marker='o', color='b')
plt.xlabel('x')
plt.ylabel('Silhouette Score')
plt.title('Silhoutte Score x K')
# Out:
# Text(0.5, 1.0, 'Silhoutte Score x K')

# %% [markdown]
# ## 8.3. Hierarchical Clustering

# %% [markdown]
# ### 8.3.1. Dendrogram

# %%
# model definition and training
hc_model = hc.linkage(X, 'ward')

# %%
hc.dendrogram(hc_model, leaf_rotation=90, leaf_font_size=8)
plt.plot()
# Out:
# []

# %%
hc.dendrogram(hc_model, truncate_mode='lastp', p=12, leaf_rotation=90, leaf_font_size=8, show_contracted=True)
plt.plot()
# Out:
# []

# %% [markdown]
# ### 8.3.2. HClustering Silhouette Score

# %%
hc_list = []

for k in clusters:
    # model definition and training
    hc_model = hc.linkage(X, 'ward')
    
    # model prediction
    labels = hc.fcluster(hc_model, k, criterion='maxclust')
    
    # metrics
    sil = M.silhouette_score(X, labels, metric='euclidean')
    hc_list.append(sil)

# %%
plt.plot(clusters, hc_list, linestyle='--', marker='o', color='b')
plt.xlabel('x')
plt.ylabel('Silhouette Score')
plt.title('Silhoutte Score x K')
# Out:
# Text(0.5, 1.0, 'Silhoutte Score x K')

# %% [markdown]
# ## 8.4. DBSCAN

# %% [markdown]
# ### 8.4.1. Finding Best Parameters

# %%
study = optuna.create_study(direction='maximize') # maximizing the precision at k
study.optimize(bayesian_opt_objective, n_trials=100); # optimizing the defined function and setting the number of trials
trial = study.best_trial

print(f'Best Silhouette Score = {trial.value} with K = {len(set(labels))}')
print(f'Best Hyperparameters = {trial.params}')
# Out:
# [I 2022-12-05 09:09:07,036] A new study created in memory with name: no-name-5ee011af-3267-4917-b23d-5ca52a7c90ed
# [I 2022-12-05 09:09:08,345] Trial 0 finished with value: 0.6996598383058367 and parameters: {'eps': 0.345, 'min_samples': 45}. Best is trial 0 with value: 0.6996598383058367.
# [I 2022-12-05 09:09:09,725] Trial 1 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 40}. Best is trial 1 with value: 0.7300935756943241.
# [I 2022-12-05 09:09:10,688] Trial 2 finished with value: 0.6996598383058367 and parameters: {'eps': 0.35, 'min_samples': 25}. Best is trial 1 with value: 0.7300935756943241.
# [I 2022-12-05 09:09:11,660] Trial 3 finished with value: 0.7300935756943241 and parameters: {'eps': 0.37, 'min_samples': 20}. Best is trial 1 with value: 0.7300935756943241.
# [I 2022-12-05 09:09:12,481] Trial 4 finished with value: 0.6817317400448681 and parameters: {'eps': 0.31, 'min_samples': 35}. Best is trial 1 with value: 0.7300935756943241.
# [I 2022-12-05 09:09:13,327] Trial 5 finished with value: 0.6996598383058367 and parameters: {'eps': 0.355, 'min_samples': 45}. Best is trial 1 with value: 0.7300935756943241.
# [I 2022-12-05 09:09:14,162] Trial 6 finished with value: 0.7412691441970682 and parameters: {'eps': 0.395, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:15,008] Trial 7 finished with value: 0.7203852332935533 and parameters: {'eps': 0.345, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:15,832] Trial 8 finished with value: 0.7203852332935533 and parameters: {'eps': 0.33999999999999997, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:16,664] Trial 9 finished with value: 0.70835810232649 and parameters: {'eps': 0.305, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:17,668] Trial 10 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:18,518] Trial 11 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:19,379] Trial 12 finished with value: 0.7300935756943241 and parameters: {'eps': 0.38, 'min_samples': 20}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:20,216] Trial 13 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:21,083] Trial 14 finished with value: 0.7300935756943241 and parameters: {'eps': 0.37, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:21,948] Trial 15 finished with value: 0.7300935756943241 and parameters: {'eps': 0.385, 'min_samples': 30}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:22,794] Trial 16 finished with value: 0.7412691441970682 and parameters: {'eps': 0.37, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:23,632] Trial 17 finished with value: 0.7203852332935533 and parameters: {'eps': 0.32999999999999996, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:24,489] Trial 18 finished with value: 0.7300935756943241 and parameters: {'eps': 0.4, 'min_samples': 25}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:25,343] Trial 19 finished with value: 0.7300935756943241 and parameters: {'eps': 0.365, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:26,222] Trial 20 finished with value: 0.7300935756943241 and parameters: {'eps': 0.38, 'min_samples': 20}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:27,093] Trial 21 finished with value: 0.7412691441970682 and parameters: {'eps': 0.39, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:27,955] Trial 22 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:28,821] Trial 23 finished with value: 0.7300935756943241 and parameters: {'eps': 0.4, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:29,701] Trial 24 finished with value: 0.7297568658935434 and parameters: {'eps': 0.36, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:30,574] Trial 25 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 50}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:31,428] Trial 26 finished with value: 0.7300935756943241 and parameters: {'eps': 0.38, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:32,290] Trial 27 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:33,150] Trial 28 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:34,008] Trial 29 finished with value: 0.7300935756943241 and parameters: {'eps': 0.375, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:34,862] Trial 30 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 30}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:35,717] Trial 31 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:36,597] Trial 32 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:37,452] Trial 33 finished with value: 0.7300935756943241 and parameters: {'eps': 0.365, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:38,313] Trial 34 finished with value: 0.7300935756943241 and parameters: {'eps': 0.385, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:39,171] Trial 35 finished with value: 0.7412691441970682 and parameters: {'eps': 0.395, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:40,042] Trial 36 finished with value: 0.7185214004262026 and parameters: {'eps': 0.37, 'min_samples': 40}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:40,908] Trial 37 finished with value: 0.7300935756943241 and parameters: {'eps': 0.395, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:41,764] Trial 38 finished with value: 0.6899935592922278 and parameters: {'eps': 0.32999999999999996, 'min_samples': 20}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:42,626] Trial 39 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:43,500] Trial 40 finished with value: 0.7203852332935533 and parameters: {'eps': 0.355, 'min_samples': 25}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:44,359] Trial 41 finished with value: 0.7412691441970682 and parameters: {'eps': 0.395, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:45,206] Trial 42 finished with value: 0.7300935756943241 and parameters: {'eps': 0.395, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:46,044] Trial 43 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:46,897] Trial 44 finished with value: 0.7412691441970682 and parameters: {'eps': 0.39, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:47,745] Trial 45 finished with value: 0.7300935756943241 and parameters: {'eps': 0.395, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:48,597] Trial 46 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:49,445] Trial 47 finished with value: 0.7300935756943241 and parameters: {'eps': 0.385, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:50,308] Trial 48 finished with value: 0.7300935756943241 and parameters: {'eps': 0.4, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:51,146] Trial 49 finished with value: 0.6899935592922278 and parameters: {'eps': 0.33499999999999996, 'min_samples': 35}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:51,980] Trial 50 finished with value: 0.7203852332935533 and parameters: {'eps': 0.315, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:52,814] Trial 51 finished with value: 0.7412691441970682 and parameters: {'eps': 0.38, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:53,654] Trial 52 finished with value: 0.7412691441970682 and parameters: {'eps': 0.365, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:54,523] Trial 53 finished with value: 0.7297568658935434 and parameters: {'eps': 0.35, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:55,468] Trial 54 finished with value: 0.7300935756943241 and parameters: {'eps': 0.365, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:56,411] Trial 55 finished with value: 0.7300935756943241 and parameters: {'eps': 0.395, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:57,339] Trial 56 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:58,251] Trial 57 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:59,101] Trial 58 finished with value: 0.7203852332935533 and parameters: {'eps': 0.36, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:09:59,967] Trial 59 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:00,815] Trial 60 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:01,823] Trial 61 finished with value: 0.7412691441970682 and parameters: {'eps': 0.395, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:02,748] Trial 62 finished with value: 0.7412691441970682 and parameters: {'eps': 0.38, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:03,617] Trial 63 finished with value: 0.7300935756943241 and parameters: {'eps': 0.385, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:04,502] Trial 64 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:05,397] Trial 65 finished with value: 0.7412691441970682 and parameters: {'eps': 0.39, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:06,269] Trial 66 finished with value: 0.7300935756943241 and parameters: {'eps': 0.385, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:07,280] Trial 67 finished with value: 0.7412691441970682 and parameters: {'eps': 0.38, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:08,203] Trial 68 finished with value: 0.7185214004262026 and parameters: {'eps': 0.38, 'min_samples': 50}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:09,219] Trial 69 finished with value: 0.7300935756943241 and parameters: {'eps': 0.37, 'min_samples': 15}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:10,231] Trial 70 finished with value: 0.7185214004262026 and parameters: {'eps': 0.375, 'min_samples': 45}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:11,106] Trial 71 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:12,025] Trial 72 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:13,034] Trial 73 finished with value: 0.7412691441970682 and parameters: {'eps': 0.395, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:13,939] Trial 74 finished with value: 0.7412691441970682 and parameters: {'eps': 0.39, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:14,860] Trial 75 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:15,945] Trial 76 finished with value: 0.7300935756943241 and parameters: {'eps': 0.4, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:16,870] Trial 77 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:17,775] Trial 78 finished with value: 0.7412691441970682 and parameters: {'eps': 0.37, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:18,637] Trial 79 finished with value: 0.7300935756943241 and parameters: {'eps': 0.395, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:19,481] Trial 80 finished with value: 0.7412691441970682 and parameters: {'eps': 0.375, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:20,342] Trial 81 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:21,200] Trial 82 finished with value: 0.7412691441970682 and parameters: {'eps': 0.385, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:22,039] Trial 83 finished with value: 0.7300935756943241 and parameters: {'eps': 0.38, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:22,896] Trial 84 finished with value: 0.7412691441970682 and parameters: {'eps': 0.39, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:23,811] Trial 85 finished with value: 0.7412691441970682 and parameters: {'eps': 0.38, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:24,656] Trial 86 finished with value: 0.7300935756943241 and parameters: {'eps': 0.37, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:25,510] Trial 87 finished with value: 0.7300935756943241 and parameters: {'eps': 0.375, 'min_samples': 35}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:26,351] Trial 88 finished with value: 0.7297568658935434 and parameters: {'eps': 0.36, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:27,184] Trial 89 finished with value: 0.7297568658935434 and parameters: {'eps': 0.355, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:28,076] Trial 90 finished with value: 0.7412691441970682 and parameters: {'eps': 0.365, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:29,028] Trial 91 finished with value: 0.7412691441970682 and parameters: {'eps': 0.365, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:29,968] Trial 92 finished with value: 0.7412691441970682 and parameters: {'eps': 0.38, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:30,824] Trial 93 finished with value: 0.7300935756943241 and parameters: {'eps': 0.365, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:31,745] Trial 94 finished with value: 0.7412691441970682 and parameters: {'eps': 0.39, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:32,605] Trial 95 finished with value: 0.7300935756943241 and parameters: {'eps': 0.39, 'min_samples': 40}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:33,489] Trial 96 finished with value: 0.7412691441970682 and parameters: {'eps': 0.395, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:34,369] Trial 97 finished with value: 0.7412691441970682 and parameters: {'eps': 0.4, 'min_samples': 5}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:35,240] Trial 98 finished with value: 0.7300935756943241 and parameters: {'eps': 0.4, 'min_samples': 25}. Best is trial 6 with value: 0.7412691441970682.
# [I 2022-12-05 09:10:36,102] Trial 99 finished with value: 0.7300935756943241 and parameters: {'eps': 0.4, 'min_samples': 10}. Best is trial 6 with value: 0.7412691441970682.
# Best Silhouette Score = 0.7412691441970682 with K = 8
# Best Hyperparameters = {'eps': 0.395, 'min_samples': 5}

# %% [markdown]
# ### 8.4.2. Apply Model

# %%
eps = 0.39
min_samples = 5

# model definition
dbscan_model = C.DBSCAN(eps=eps, min_samples=min_samples, n_jobs=-1)

# model training & predict
labels = dbscan_model.fit_predict(X)

sil = M.silhouette_score(X, labels, metric='euclidean')
print('Silhouette Score: {}'.format(sil))
print('Number of Clusters: {}'.format(len(set(labels))))
print(set(labels))
# Out:
# Silhouette Score: 0.7412691441970682
# Number of Clusters: 2
# {0, -1}

# %% [markdown]
# ## 8.5. Silhouette Analysis

# %% [markdown]
# ### 8.5.1. KMeans

# %%
fig, ax = plt.subplots( 4, 2, figsize=(25, 18) )

for k in clusters:
    km = C.KMeans( n_clusters=k, init='random', n_init=10, max_iter=100, random_state=42 )
    q, mod = divmod( k, 2 )
    
    visualizer = SilhouetteVisualizer( km, colors='yellowbrick', ax=ax[q-1][mod] )
    visualizer.fit( X )
    visualizer.finalize()

# %% [markdown]
# ### 8.5.2. GMM

# %%
fig, ax = plt.subplots(4, 2)
fig.set_size_inches(25, 20)

for k in clusters:
    q, mod = divmod(k, 2)
    
    ax[q-1, mod].set_xlim([-0.1, 1])
    ax[q-1, mod].set_ylim([0, len(X) + (k+1)*10])
    
    # model definition
    gmm_model = mx.GaussianMixture(n_components=k, n_init=10)
    
    # model training
    gmm_model.fit(X)
    
    # model predict
    labels = gmm_model.predict(X)
    
    # performance
    SS = M.silhouette_score(X, labels, metric='euclidean')
    print('For k = {}, Silhoutte Score = {}.'.format(k, SS))
    
    samples_silhouette_values = M.silhouette_samples(X, labels)
    
    y_lower = 10
    
    for i in range(k):
        # select clusters
        ith_sample_silhouette_values = samples_silhouette_values[labels==i]
        
        # sort values
        ith_sample_silhouette_values.sort()
        
        # size clusters
        size_cluster_i = ith_sample_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        cmap = cm.get_cmap('Spectral')
        color = cmap(i/k)
        
        ax[q-1, mod].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_sample_silhouette_values, alpha=0.7)
        ax[q-1, mod].text(-0.05, y_lower+0.05*size_cluster_i, str(i))
        
        y_lower = y_upper+10
    
    ax[q-1, mod].set_yticks([])
    ax[q-1, mod].set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
    ax[q-1, mod].set_title('Number of Clusters: %d' %k)
    ax[q-1, mod].set_xlabel('Silouette Coefficient Value')
    ax[q-1, mod].set_ylabel('Cluster Label')
# Out:
# For k = 2, Silhoutte Score = 0.0690065430946412.
# For k = 3, Silhoutte Score = 0.021044998466147054.
# For k = 4, Silhoutte Score = -0.09260020583732623.
# For k = 5, Silhoutte Score = -0.1389874949310644.
# For k = 6, Silhoutte Score = -0.19893424900402418.
# For k = 7, Silhoutte Score = -0.15391047531615354.
# For k = 8, Silhoutte Score = -0.2105723783407583.

# %% [markdown]
# ### 8.5.3. Hierarchical Clustering

# %%
fig, ax = plt.subplots(4, 2)
fig.set_size_inches(25, 20)

for k in clusters:
    q, mod = divmod(k, 2)
    
    ax[q-1, mod].set_xlim([-0.1, 1])
    ax[q-1, mod].set_ylim([0, len(X) + (k+1)*10])
    
    # model definition and training
    hc_model = hc.linkage(X, 'ward')
    
    # model predict
    labels = hc.fcluster(hc_model, k, criterion='maxclust')
    
    # performance
    SS = M.silhouette_score(X, labels, metric='euclidean')
    print('For k = {}, Silhoutte Score = {}.'.format(k, SS))
    
    samples_silhouette_values = M.silhouette_samples(X, labels)
    
    y_lower = 10
    
    for i in range(k):
        # select clusters
        ith_sample_silhouette_values = samples_silhouette_values[labels==i]
        
        # sort values
        ith_sample_silhouette_values.sort()
        
        # size clusters
        size_cluster_i = ith_sample_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        cmap = cm.get_cmap('Spectral')
        color = cmap(i/k)
        
        ax[q-1, mod].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_sample_silhouette_values, alpha=0.7)
        ax[q-1, mod].text(-0.05, y_lower+0.05*size_cluster_i, str(i))
        
        y_lower = y_upper+10
    
    ax[q-1, mod].set_yticks([])
    ax[q-1, mod].set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
    ax[q-1, mod].set_title('Number of Clusters: %d' %k)
    ax[q-1, mod].set_xlabel('Silouette Coefficient Value')
    ax[q-1, mod].set_ylabel('Cluster Label')
# Out:
# For k = 2, Silhoutte Score = 0.6370527948644134.
# For k = 3, Silhoutte Score = 0.563341461980863.
# For k = 4, Silhoutte Score = 0.4222254219500748.
# For k = 5, Silhoutte Score = 0.3793893171599649.
# For k = 6, Silhoutte Score = 0.38748628208864727.
# For k = 7, Silhoutte Score = 0.3787868555326803.
# For k = 8, Silhoutte Score = 0.36162360868545573.

# %% [markdown]
# ## 8.6. Results

# %%
df_results = pd.DataFrame({'KMeans': kmeans_list,
                           'GMM': gmm_list,
                           'HC': hc_list}).T
df_results.columns = clusters

# %%
df_results.style.highlight_max(color='lightgreen', axis=1)
# Out:
# <style type="text/css">
# #T_848a3_row0_col0, #T_848a3_row1_col0, #T_848a3_row2_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_848a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_848a3_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_848a3_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_848a3_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_848a3_level0_col3" class="col_heading level0 col3" >5</th>
#       <th id="T_848a3_level0_col4" class="col_heading level0 col4" >6</th>
#       <th id="T_848a3_level0_col5" class="col_heading level0 col5" >7</th>
#       <th id="T_848a3_level0_col6" class="col_heading level0 col6" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_848a3_level0_row0" class="row_heading level0 row0" >KMeans</th>
#       <td id="T_848a3_row0_col0" class="data row0 col0" >0.659280</td>
#       <td id="T_848a3_row0_col1" class="data row0 col1" >0.585021</td>
#       <td id="T_848a3_row0_col2" class="data row0 col2" >0.463199</td>
#       <td id="T_848a3_row0_col3" class="data row0 col3" >0.433888</td>
#       <td id="T_848a3_row0_col4" class="data row0 col4" >0.443946</td>
#       <td id="T_848a3_row0_col5" class="data row0 col5" >0.449411</td>
#       <td id="T_848a3_row0_col6" class="data row0 col6" >0.431656</td>
#     </tr>
#     <tr>
#       <th id="T_848a3_level0_row1" class="row_heading level0 row1" >GMM</th>
#       <td id="T_848a3_row1_col0" class="data row1 col0" >0.069007</td>
#       <td id="T_848a3_row1_col1" class="data row1 col1" >0.021045</td>
#       <td id="T_848a3_row1_col2" class="data row1 col2" >-0.084014</td>
#       <td id="T_848a3_row1_col3" class="data row1 col3" >-0.138733</td>
#       <td id="T_848a3_row1_col4" class="data row1 col4" >-0.198934</td>
#       <td id="T_848a3_row1_col5" class="data row1 col5" >-0.153026</td>
#       <td id="T_848a3_row1_col6" class="data row1 col6" >-0.153489</td>
#     </tr>
#     <tr>
#       <th id="T_848a3_level0_row2" class="row_heading level0 row2" >HC</th>
#       <td id="T_848a3_row2_col0" class="data row2 col0" >0.637053</td>
#       <td id="T_848a3_row2_col1" class="data row2 col1" >0.563341</td>
#       <td id="T_848a3_row2_col2" class="data row2 col2" >0.422225</td>
#       <td id="T_848a3_row2_col3" class="data row2 col3" >0.379389</td>
#       <td id="T_848a3_row2_col4" class="data row2 col4" >0.387486</td>
#       <td id="T_848a3_row2_col5" class="data row2 col5" >0.378787</td>
#       <td id="T_848a3_row2_col6" class="data row2 col6" >0.361624</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 9.0. MODEL TRAINING

# %% [markdown]
# ## 9.1. K-Means

# %%
# model definition
k = 3
kmeans = C.KMeans(init='random', n_clusters=k, n_init=100, max_iter=300)

# model training
kmeans.fit(X)

# clustering
labels = kmeans.labels_

# %% [markdown]
# ### 9.1.2. K-Means cluster validation

# %%
# WSS (Within-Cluster Sum of Square)
print('WSS value: {}'.format(kmeans.inertia_))

# SS (Silhouette Score)
print('SS value: {}'.format(M.silhouette_score(X, labels, metric='euclidean')))
# Out:
# WSS value: 84.16199290757503
# SS value: 0.5850210269025584

# %% [markdown]
# # 10.0. CLUSTER ANALYSIS

# %% [markdown]
# ## 10.1. Visualization Inspection

# %% [markdown]
# ### 10.1.1. Silhoutte Score

# %%
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
visualizer.fit(X)
visualizer.finalize()
# Out:
# /home/felipe/repos/insiders_clustering/insiders_env/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### 10.1.2 UMAP

# %%
# prepare dataframe for vizualization
df_viz = df_ref_7.copy()
df_viz['cluster'] = labels

# %%
reducer = umap.UMAP(n_neighbors=25, random_state=42)
embedding = reducer.fit_transform(X)

# embedding
df_viz['embedding_x'] = embedding[:, 0]
df_viz['embedding_y'] = embedding[:, 1]

# plot UMAP
sns.scatterplot(x='embedding_x',
                y='embedding_y',
                hue='cluster',
                palette=sns.color_palette('hls', n_colors=len(df_viz['cluster'].unique())),
                data=df_viz
                )
# Out:
# <AxesSubplot: xlabel='embedding_x', ylabel='embedding_y'>

# %% [markdown]
# ## 10.2. Clusters Profile

# %%
df_ref_10 = df_ref_5.copy()
df_ref_10['cluster'] = labels

# %%
# number of customer
df_cluster = df_ref_10[['customer_id', 'cluster']].groupby('cluster').count().reset_index().rename(columns={'customer_id':'qty_customers'})
df_cluster['perc_customer'] = 100*(df_cluster['qty_customers']/df_cluster['qty_customers'].sum())

# avg gross revenue
df_avg_gr = df_ref_10[['gross_revenue', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'gross_revenue':'avg_gross_revenue'})
df_cluster = pd.merge(df_cluster, df_avg_gr, on='cluster', how='left')

# avg ticket
df_avg_tk = df_ref_10[['avg_ticket', 'cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_tk, on='cluster', how='left')

# avg recency days
df_avg_rd = df_ref_10[['recency', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'recency':'avg_recency'})
df_cluster = pd.merge(df_cluster, df_avg_rd, on='cluster', how='left')

# avg frequency
df_avg_fr = df_ref_10[['frequency', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'frequency':'avg_frequency'})
df_cluster = pd.merge(df_cluster, df_avg_fr, on='cluster', how='left')

# avg_qty_returns
df_avg_qr = df_ref_10[['qty_returns', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'qty_returns':'avg_qty_returns'})
df_cluster = pd.merge(df_cluster, df_avg_qr, on='cluster', how='left')

# avg_amount_returned
df_avg_ar = df_ref_10[['amount_returned', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'amount_returned':'avg_amount_returned'})
df_cluster = pd.merge(df_cluster, df_avg_ar, on='cluster', how='left')

# avg_qty_items
df_avg_qi = df_ref_10[['qty_items', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'qty_items':'avg_qty_items'})
df_cluster = pd.merge(df_cluster, df_avg_qi, on='cluster', how='left')

# avg_assortment
df_avg_as = df_ref_10[['assortment', 'cluster']].groupby('cluster').mean().reset_index().rename(columns={'assortment':'avg_assortment'})
df_cluster = pd.merge(df_cluster, df_avg_as, on='cluster', how='left')

# avg_basket_size
df_avg_bs = df_ref_10[['avg_basket_size', 'cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, df_avg_bs, on='cluster', how='left')

# %%
df_cluster.head()
# Out:
#    cluster  qty_customers  perc_customer  avg_gross_revenue  avg_ticket  \
# 0        0           3329      58.352323        2437.898327  491.984315
# 1        1           1111      19.474145         668.231881  602.299433
# 2        2           1265      22.173532         744.968466  484.072287
#
#    avg_recency  avg_frequency  avg_qty_returns  avg_amount_returned  \
# 0    35.862121       4.762691         0.883148           105.226969
# 1   305.052205       1.015302         0.123312            77.249766
# 2   169.447431       1.633202         0.217391            27.158324
#
#    avg_qty_items  avg_assortment  avg_basket_size
# 0    1381.900571       83.006909       240.962897
# 1     234.407741       52.727273       200.448328
# 2     354.209486       49.202372       204.971248

# %% [markdown]
# ### 10.2.1. Cluster Insiders

# %% [markdown]
# - Cluster: 1
# - Number of customers: 6 (0.14% of customer base)
# - Average recency (days since last purchase): 8 days
# - Average frequency (purchases in last 365 days): 1803 purchases
# - Average gross revenue: $ 180,182.00

# %% [markdown]
# # 11.0. DEPLOY
